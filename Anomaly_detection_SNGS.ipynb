# %% [markdown]
# # Описание

# %% [markdown]
# Эта часть общей работы основана на статье "ANOMALY DETECTION IN UNIVARIATE TIME-SERIES: A
# SURVEY ON THE STATE-OF-THE-ART" (https://arxiv.org/pdf/2004.00433.pdf).
#
# An anomaly is an observation or a sequence of observations which deviates remarkably from the
# general distribution of data. Поиском таких наблюдений мы дальше и будем заниматься, рассматривая датасет дневной доходности SNGS с 2015 года.
#
# Anomaly detection является полезным в различных случаях. Например, нахождение аномалий в нашем случае может быть полезно для риск-менеджмента: будут анализироваться причины найденных аномалий, которые будут учитываться при выставлении риск-параметров. Помимо этого, регуляторы могут считать аномалии симптоном манипуляций рынком.
#
# Будем использовать метод Local Outlier Factor (LOF) для поиска аномалий. По просту говоря, LOF - это kNN на максималках (учитывает дополнительно плотность объектов, рассчитывая "под капотом" помимо обычного расстояния другие метрики). Более подробное описание метода можно найти в статье.

# %% [markdown]
# # Библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import f1_score

from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# # Подготовка данных

# %%
df = pd.read_csv('df_r.csv')
data = np.array(df['SNGS'])

# %% [markdown]
# Ранее было замечено, что в районе 400 наблюдения имеется пологий участок. Это связано с особенностями проведеня торгов на фондовом рынке в феврале-марте.

# %% [markdown]
# # Деление на тест и трейн

# %%
plt.figure(figsize = (20, 10))
plt.title('График дневной доходности SNGS')
plt.xlabel('Индекс')
plt.ylabel('Доходность')
plt.plot(data)
plt.axvline(1300, color='red', linestyle='dotted', linewidth=3)

# %% [markdown]
# Чтобы адекватно подбрать параметры, а затем оценить модель, трейн и тест должны включаnь нормальные и аномальные данные.
#
# Трейн будет идти до 1300 индекса включительно, а после тест. Таким образом мы включим в них нормальные и аномальные участки.

# %%
train = data[:1301]

# %%
test = data[1301:]

# %% [markdown]
# # Разметка данных

# %% [markdown]
# Размечать данные будем методом, основанном на IQR. Более конкретно: будем считать аномалиями те точки, значения которых больше q2 + 1.5 * IQR или меньше q1 - 1.5 * IQR (где q2 - 0.75 квантиль, q1 - 0.25 квантиль, iqr - интерквартильный размах). (для подробностей см. https://towardsdatascience.com/why-1-5-in-iqr-method-of-outlier-detection-5d07fdc82097)

# %% [markdown]
# #### Разметим трейн

# %%
q1_tr = np.quantile(train, 0.25)
q2_tr = np.quantile(train, 0.75)
iqr_tr = q2_tr - q1_tr
lower_tr = q1_tr - 1.5*iqr_tr
upper_tr = q2_tr + 1.5*iqr_tr
ind_tr = np.where((train > upper_tr) | (train < lower_tr))[0]

# %%
real_tr = train.copy()
real_tr[ind_tr] = -1
real_tr[list(set(np.arange(0, 1301)) - set(ind_tr))] = 1

# %%
plt.figure(figsize = (20, 10))
plt.title('Размеченный график трейна дневной доходности SNGS')
plt.xlabel('Индекс')
plt.ylabel('Доходность')
plt.plot(train)
plt.plot(ind_tr, train[ind_tr], 'ro')

# %% [markdown]
# #### Разметим тест

# %%
q1_te = np.quantile(test, 0.25)
q2_te = np.quantile(test, 0.75)
iqr_te = q2_te - q1_te
lower_te = q1_te - 1.5*iqr_te
upper_te = q2_te + 1.5*iqr_te
ind_te = np.where((test > upper_te) | (test < lower_te))[0]

# %%
real_te = test.copy()
real_te[ind_te] = -1
real_te[list(set(np.arange(0, len(real_te))) - set(ind_te))] = 1

# %%
plt.figure(figsize = (20, 10))
plt.title('Размеченный график теста дневной доходности SNGS')
plt.xlabel('Индекс')
plt.ylabel('Доходность')
plt.plot(test)
plt.plot(ind_te, test[ind_te], 'ro')

# %% [markdown]
# # Подбор гиперпараметров

# %% [markdown]
# Для LOF необходимо подобрать число соседей, будем использовать F1 метрику для оценки качества. Так как данных не очень много, можно пройтись и циклом.

# %%
train = train.reshape(-1, 1)

# %%
f1_s = []
for n in np.arange(1, 300):
    clf = LocalOutlierFactor(n_neighbors = n)
    pred = clf.fit_predict(train)
    f1_s.append((f1_score(real_tr, pred), n))

# %%
f1_s.sort(reverse = True)
f1_s[0:5]
# Out:
# [(0.9983700081499592, 65),
#  (0.9983700081499592, 64),
#  (0.997557003257329, 63),
#  (0.9975530179445351, 66),
#  (0.9971509971509972, 62)]

# %%
clf = LocalOutlierFactor(n_neighbors = 65)

# %%
pred = clf.fit_predict(train)

# %%
plt.figure(figsize = (20, 10))
plt.plot(train)
plt.plot(np.where(pred == -1)[0], train[np.where(pred == -1)[0]], 'ro')
for i in np.where(pred == -1)[0]:
    print('Аномалия найдена', df['Дата торгов'].iloc[i], 'и составила', df['SNGS'].iloc[i])
# Out:
# Аномалия найдена 2015-06-16 и составила 0.0341813641329797
# Аномалия найдена 2015-07-08 и составила -0.031787874089006
# Аномалия найдена 2015-07-16 и составила 0.02882797731569
# Аномалия найдена 2015-08-24 и составила -0.0492926284437826
# Аномалия найдена 2015-10-05 и составила 0.0375150060024009
# Аномалия найдена 2016-01-19 и составила 0.0446333687566418
# Аномалия найдена 2016-01-22 и составила 0.0288475618685019
# Аномалия найдена 2016-02-12 и составила 0.0364496382860323
# Аномалия найдена 2016-05-04 и составила -0.0393712143063167
# Аномалия найдена 2016-11-02 и составила 0.043207616257781
# Аномалия найдена 2017-05-25 и составила 0.0454957404386441
# Аномалия найдена 2017-05-29 и составила 0.0404367855314792
# Аномалия найдена 2017-06-01 и составила -0.0937808489634748
# Аномалия найдена 2017-06-02 и составила -0.0357661583151779
# Аномалия найдена 2017-06-15 и составила -0.0396700706991359
# Аномалия найдена 2017-08-01 и составила 0.0339787395596051
# Аномалия найдена 2018-01-31 и составила -0.0335913057796805
# Аномалия найдена 2018-04-10 и составила 0.0326377742108078
# Аномалия найдена 2019-09-02 и составила 0.0861049519586105
# Аномалия найдена 2019-09-03 и составила 0.1864579789043891
# Аномалия найдена 2019-09-04 и составила 0.03742472039002
# Аномалия найдена 2019-09-05 и составила -0.0587422252937111
# Аномалия найдена 2019-09-06 и составила -0.0312775330396475
# Аномалия найдена 2019-09-11 и составила 0.056988602279544
# Аномалия найдена 2019-09-12 и составила 0.044693530079455
# Аномалия найдена 2019-09-18 и составила -0.0406624478255015
# Аномалия найдена 2019-10-01 и составила 0.0308063600227143
# Аномалия найдена 2019-10-23 и составила 0.0934156378600821
# Аномалия найдена 2019-10-24 и составила 0.0568310124200226
# Аномалия найдена 2019-10-25 и составила 0.1048195631528964
# Аномалия найдена 2019-10-29 и составила -0.0402792696025778
# Аномалия найдена 2019-11-01 и составила 0.0488739261667052
# Аномалия найдена 2019-11-05 и составила 0.0335362479247371
# Аномалия найдена 2019-11-11 и составила 0.0364806866952788
# Аномалия найдена 2019-12-12 и составила 0.071864406779661
# Аномалия найдена 2019-12-23 и составила 0.0471492366808598
# Аномалия найдена 2019-12-24 и составила 0.0288604581969651
# Аномалия найдена 2020-01-21 и составила -0.0360003682902126
# Аномалия найдена 2020-01-22 и составила -0.0467048710601719
# Аномалия найдена 2020-01-23 и составила -0.037471195271015
# Аномалия найдена 2020-01-27 и составила -0.030704021503153
# Аномалия найдена 2020-01-29 и составила 0.0384366227596631
# Аномалия найдена 2020-02-03 и составила -0.0474119643614764
# Аномалия найдена 2020-02-05 и составила 0.0508623530704163
# Аномалия найдена 2020-02-11 и составила 0.0367663102771111
# Аномалия найдена 2020-02-25 и составила -0.032912198747213
# Аномалия найдена 2020-02-26 и составила -0.0420463278076627
# Аномалия найдена 2020-02-27 и составила -0.0552372220948889
# Аномалия найдена 2020-02-28 и составила -0.0830907326540513
# Аномалия найдена 2020-03-06 и составила -0.0535170221221352
# Аномалия найдена 2020-03-10 и составила -0.0943317004898531
# Аномалия найдена 2020-03-12 и составила -0.0703359091625925
# Аномалия найдена 2020-03-16 и составила -0.1036973344797936
# Аномалия найдена 2020-03-18 и составила -0.031867920906124
# Аномалия найдена 2020-03-19 и составила 0.0309339678762641
# Аномалия найдена 2020-03-20 и составила 0.0650125024043084
# Аномалия найдена 2020-03-23 и составила -0.0516525194148455
# Аномалия найдена 2020-03-24 и составила 0.0573224147781376
# Аномалия найдена 2020-03-25 и составила 0.0538544668587895
# Аномалия найдена 2020-03-26 и составила 0.1073320799863272
# Аномалия найдена 2020-03-31 и составила 0.050104049943973
# Аномалия найдена 2020-04-01 и составила 0.0408536585365854
# Аномалия найдена 2020-04-02 и составила 0.0502343292325716
# Аномалия найдена 2020-04-15 и составила -0.0549465797141667
# Аномалия найдена 2020-04-22 и составила 0.0533071579583207
# Аномалия найдена 2020-04-28 и составила 0.0338862895221891
# Аномалия найдена 2020-05-14 и составила 0.0300587511955185
# Аномалия найдена 2020-05-15 и составила 0.065658575407879
# Аномалия найдена 2020-05-25 и составила 0.0470483233456585
# Аномалия найдена 2020-05-27 и составила -0.0306013521527695
# Аномалия найдена 2020-06-16 и составила 0.0307237434117495
# Аномалия найдена 2020-07-14 и составила -0.0386316337148803

# %%
print('F1 метрика составила', f1_score(real_tr, pred))
# Out:
# F1 метрика составила 0.9983700081499592

# %% [markdown]
# Отлично!

# %% [markdown]
# # Тестирование

# %%
test = test.reshape(-1, 1)

# %%
clf = LocalOutlierFactor(n_neighbors = 65)

# %%
pred = clf.fit_predict(test)

# %%
plt.figure(figsize = (20, 10))
plt.plot(np.arange(1301, 2020), test)
plt.plot(np.where(pred == -1)[0]+1301, test[np.where(pred == -1)[0]], 'ro')
for i in np.where(pred == -1)[0]+1301:
    print('Аномалия найдена', df['Дата торгов'].iloc[i], 'и составила', df['SNGS'].iloc[i])
# Out:
# Аномалия найдена 2021-03-09 и составила 0.041534008683068
# Аномалия найдена 2021-09-30 и составила 0.0376282782212086
# Аномалия найдена 2021-11-11 и составила 0.1118430683648075
# Аномалия найдена 2021-11-12 и составила 0.1864384463462804
# Аномалия найдена 2021-11-18 и составила -0.0566395361801761
# Аномалия найдена 2021-11-30 и составила -0.0433942827710531
# Аномалия найдена 2021-12-15 и составила 0.1087642298724455
# Аномалия найдена 2021-12-20 и составила -0.0398846105606422
# Аномалия найдена 2022-01-13 и составила -0.037873180360227
# Аномалия найдена 2022-01-14 и составила -0.0350044877548402
# Аномалия найдена 2022-01-18 и составила -0.0516389177939646
# Аномалия найдена 2022-01-24 и составила -0.0452205370808404
# Аномалия найдена 2022-02-21 и составила -0.1064262867112532
# Аномалия найдена 2022-02-22 и составила -0.0691506671005532
# Аномалия найдена 2022-02-24 и составила -0.2859639923090368
# Аномалия найдена 2022-02-25 и составила 0.1241126070991432
# Аномалия найдена 2022-03-24 и составила 0.0971254355400697
# Аномалия найдена 2022-03-25 и составила -0.0647082175466455
# Аномалия найдена 2022-03-28 и составила -0.0415959252971137
# Аномалия найдена 2022-03-31 и составила 0.1039106145251396
# Аномалия найдена 2022-04-01 и составила 0.0748987854251012
# Аномалия найдена 2022-04-04 и составила 0.0497175141242937
# Аномалия найдена 2022-04-05 и составила -0.0364190886257624
# Аномалия найдена 2022-04-15 и составила -0.0352941176470587
# Аномалия найдена 2022-04-19 и составила -0.042655014565127
# Аномалия найдена 2022-04-25 и составила -0.0355107409031126
# Аномалия найдена 2022-04-27 и составила 0.0450530035335688
# Аномалия найдена 2022-05-13 и составила -0.0345426895502933
# Аномалия найдена 2022-05-18 и составила 0.0411764705882353
# Аномалия найдена 2022-06-16 и составила 0.0448585231193927
# Аномалия найдена 2022-06-28 и составила 0.1253869969040248
# Аномалия найдена 2022-06-30 и составила -0.0602571483400499
# Аномалия найдена 2022-07-01 и составила 0.053910557484174
# Аномалия найдена 2022-07-05 и составила 0.0399139111719819
# Аномалия найдена 2022-07-21 и составила 0.0571370059389719
# Аномалия найдена 2022-07-29 и составила 0.062596599690881
# Аномалия найдена 2022-08-02 и составила -0.0370304432971336
# Аномалия найдена 2022-08-10 и составила 0.0356868764389869
# Аномалия найдена 2022-09-02 и составила 0.061148250098309
# Аномалия найдена 2022-09-20 и составила -0.0678881388621022
# Аномалия найдена 2022-09-21 и составила -0.1086281812538795
# Аномалия найдена 2022-09-23 и составила -0.0390642743583919
# Аномалия найдена 2022-09-26 и составила -0.1437012526589459
# Аномалия найдена 2022-10-03 и составила 0.0384939589772407
# Аномалия найдена 2022-10-07 и составила -0.0411577270313329
# Аномалия найдена 2022-10-25 и составила 0.0398679532757745
# Аномалия найдена 2022-12-02 и составила 0.0496780128794849
# Аномалия найдена 2023-01-27 и составила 0.05175983436853
# Аномалия найдена 2023-02-15 и составила -0.0382081686429513
# Аномалия найдена 2023-04-21 и составила 0.0398
# Аномалия найдена 2023-05-15 и составила 0.0393634840871022

# %%
print('F1 метрика составила', f1_score(real_te, pred))
# Out:
# F1 метрика составила 0.9992509363295881

# %% [markdown]
# Прекрасный результат!
