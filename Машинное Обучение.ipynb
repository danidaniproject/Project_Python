# %% [markdown]
# Одна из основных задач нашей работы - настроить модель для предсказания цены акции на основе различных признаков. На данный момент мы планируем использовать для этого градиентный бустинг (в целом он неплохо себя зарекомендовал на практике, как можно судить), а именно CatBoostRegressor. Одно из преимуществ этой модели состоит в том, что она требует минимального преобразования категориальных признаков. То есть изначально она хорошо работает как с числами, так и категориями. Для оптимизации гиперпараметров на данный момент планируем использовать Optuna.
#
# Нами был использван ChatGPT чтобы понять как использовать кат буст! Сообщение ниже сгенерировано нейросетью.
# CatBoostRegressor может быть применен для предсказания временных рядов по следующему алгоритму:
#
# 1. Подготовьте данные. Необходимо иметь исторические данные временного ряда и тестовые данные для проверки точности модели.
#
# 2. Разбейте данные на обучающую и проверочную части. Обычно принято использовать 70% данных для обучения и 30% для проверки.
#
# 3. Обработайте данные. Выполните необходимую предобработку данных, например, заполнение пропущенных значений, шкалирование и т.д.
#
# 4. Создайте модель. Используйте CatBoostRegressor для создания модели, передав ей обработанные данные.
#
# 5. Обучите модель. Обучите модель на обучающих данных с помощью метода fit.
#
# 6. Протестируйте модель. Протестируйте модель на проверочных данных и оцените ее точность.
#
# 7. Примените модель для предсказания будущих значений временного ряда.
#
# Важно заметить, что для успешного прогнозирования временных рядов важно правильно определить гиперпараметры модели, такие как глубина деревьев, шаг градиентного бустинга, скорость обучения и т.д.
